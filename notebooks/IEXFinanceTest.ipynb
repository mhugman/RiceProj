# %%
from iexfinance.stocks import Stock
import iexfinance as iex
import os
import iextoken

#os.environ['IEX_TOKEN'] = iextoken.IEX_TOKEN

# %%
aapl = Stock('AAPL', output_format='pandas', token=iextoken.IEX_TOKEN)

# %%
aapl.get_quote()
# Out:
#                                      AAPL
# avgTotalVolume                   28111644
# calculationPrice                    close
# change                              -3.23
# changePercent                    -0.01462
# close                              217.73
# closeTime                   1569009600841
# companyName                   Apple, Inc.
# delayedPrice                       217.73
# delayedPriceTime            1569009600841
# extendedChange                       0.02
# extendedChangePercent               9e-05
# extendedPrice                      217.75
# extendedPriceTime           1569110362396
# high                               222.56
# iexAskPrice                          None
# iexAskSize                           None
# iexBidPrice                          None
# iexBidSize                           None
# iexLastUpdated                       None
# iexMarketPercent                     None
# iexRealtimePrice                     None
# ...
